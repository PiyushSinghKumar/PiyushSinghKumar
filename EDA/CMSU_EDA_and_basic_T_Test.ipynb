# %% [markdown]
# The Student News Service at Clear Mountain State University (CMSU) has decided to gather data about the undergraduate students that attend CMSU. CMSU creates and distributes a survey of 14 questions and receives responses from 62 undergraduates (stored in the Survey data set).

# %%
survey = pd.read_csv('Survey.csv')
survey
# Out:
#     ID  Gender  Age      Class                   Major Grad Intention  GPA  \
# 0    1  Female   20     Junior                   Other            Yes  2.9
# 1    2    Male   23     Senior              Management            Yes  3.6
# 2    3    Male   21     Junior                   Other            Yes  2.5
# 3    4    Male   21     Junior                     CIS            Yes  2.5
# 4    5    Male   23     Senior                   Other      Undecided  2.8
# ..  ..     ...  ...        ...                     ...            ...  ...
# 57  58  Female   21     Senior  International Business             No  2.4
# 58  59  Female   20     Junior                     CIS             No  2.9
# 59  60  Female   20  Sophomore                     CIS             No  2.5
# 60  61  Female   23     Senior              Accounting            Yes  3.5
# 61  62  Female   23     Senior       Economics/Finance             No  3.2
#
# ...

# %%
survey.describe(include='all')
# Out:
#                ID  Gender        Age   Class                Major  \
# count   62.000000      62  62.000000      62                   62
# unique        NaN       2        NaN       3                    8
# top           NaN  Female        NaN  Senior  Retailing/Marketing
# freq          NaN      33        NaN      31                   14
# mean    31.500000     NaN  21.129032     NaN                  NaN
# std     18.041619     NaN   1.431311     NaN                  NaN
# min      1.000000     NaN  18.000000     NaN                  NaN
# 25%     16.250000     NaN  20.000000     NaN                  NaN
# 50%     31.500000     NaN  21.000000     NaN                  NaN
# 75%     46.750000     NaN  22.000000     NaN                  NaN
# max     62.000000     NaN  26.000000     NaN                  NaN
#
#        Grad Intention        GPA Employment     Salary  Social Networking  \
# count              62  62.000000         62  62.000000          62.000000
# ...

# %%
survey.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID                 62 non-null     int64
#  1   Gender             62 non-null     object
#  2   Age                62 non-null     int64
#  3   Class              62 non-null     object
#  4   Major              62 non-null     object
#  5   Grad Intention     62 non-null     object
#  6   GPA                62 non-null     float64
#  7   Employment         62 non-null     object
#  8   Salary             62 non-null     float64
#  9   Social Networking  62 non-null     int64
#  10  Satisfaction       62 non-null     int64
#  11  Spending           62 non-null     int64
#  12  Computer           62 non-null     object
#  13  Text Messages      62 non-null     int64
# dtypes: float64(2), int64(6), object(6)
# memory usage: 6.9+ KB

# %%
pd.crosstab(survey['Gender'],survey['Major'])
# Out:
# Major   Accounting  CIS  Economics/Finance  International Business  \
# Gender
# Female           3    3                  7                       4
# Male             4    1                  4                       2
#
# Major   Management  Other  Retailing/Marketing  Undecided
# Gender
# Female           4      3                    9          0
# Male             6      4                    5          3

# %%
pd.crosstab(survey['Gender'],survey['Grad Intention'])
# Out:
# Grad Intention  No  Undecided  Yes
# Gender
# Female           9         13   11
# Male             3          9   17

# %%
pd.crosstab(survey['Gender'],survey['Employment'])
# Out:
# Employment  Full-Time  Part-Time  Unemployed
# Gender
# Female              3         24           6
# Male                7         19           3

# %%
pd.crosstab(survey['Gender'],survey['Computer'])
# Out:
# Computer  Desktop  Laptop  Tablet
# Gender
# Female          2      29       2
# Male            3      26       0

# %%
pd.crosstab(survey['Gender'],survey['Gender'])
# Out:
# Gender  Female  Male
# Gender
# Female      33     0
# Male         0    29

# %%
survey['Gender'].value_counts('Male')
# Out:
# Female    0.532258
# Male      0.467742
# Name: Gender, dtype: float64

# %%
Sub=survey[['Gender','Grad Intention']]

# %%
Sub2 = Sub[(Sub['Grad Intention'] == "Yes") |  (Sub['Grad Intention']== "No")]

# %%
pd.crosstab(Sub2['Gender'],Sub2['Grad Intention'])
# Out:
# Grad Intention  No  Yes
# Gender
# Female           9   11
# Male             3   17

# %%
survey[['Gender','GPA']]

# %%
pd.crosstab(survey['Gender'],survey['GPA'])
# Out:
# GPA     2.3  2.4  2.5  2.6  2.8  2.9  3.0  3.1  3.2  3.3  3.4  3.5  3.6  3.7  \
# Gender
# Female    1    1    2    0    1    3    5    2    4    3    2    4    1    2
# Male      0    0    4    2    2    1    2    5    2    2    5    2    2    0
#
# GPA     3.8  3.9
# Gender
# Female    1    1
# Male      0    0

# %%
pd.crosstab(survey['Gender'],survey['GPA']<3)
# Out:
# GPA     False  True
# Gender
# Female     25      8
# Male       20      9

# %%
pd.crosstab(survey['Gender'],survey['Salary']>=50)
# Out:
# Salary  False  True
# Gender
# Female     15     18
# Male       15     14

# %%
plt.figure(figsize= (20,15))
plt.subplot(4,1,1)
sns.boxplot('GPA', data=survey)
plt.subplot(4,1,2)
sns.boxplot('Salary', data=survey)
plt.subplot(4,1,3)
sns.boxplot('Spending', data=survey)
plt.subplot(4,1,4)
sns.boxplot('Text Messages', data=survey)

# %%
plt.figure(figsize= (18,14))
plt.subplot(4,1,1)
sns.distplot(survey['GPA'])
plt.subplot(4,1,2)
sns.distplot(survey['Salary'])
plt.subplot(4,1,3)
sns.distplot(survey['Spending'])
plt.subplot(4,1,4)
sns.distplot(survey['Text Messages'])

# %%
shingles = pd.read_csv('A&B shingles.csv')

# %%
shingles.describe()
# Out:
#                A          B
# count  36.000000  31.000000
# mean    0.316667   0.273548
# std     0.135731   0.137296
# min     0.130000   0.100000
# 25%     0.207500   0.160000
# 50%     0.290000   0.230000
# 75%     0.392500   0.400000
# max     0.720000   0.580000

# %%
shingles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       36 non-null     float64
#  1   B       31 non-null     float64
# dtypes: float64(2)
# memory usage: 704.0 bytes

# %%
#T_test one sample for A
t_statisticA, p_valueA = stats.ttest_1samp(shingles['A'], 0.35,nan_policy='omit')
p_valueA=p_valueA/2
print('One sample t test \nt statistic: {0} p value for A: {1} '.format(t_statisticA, p_valueA))
# Out:
# One sample t test
# t statistic: -1.4735046253382782 p value for A: 0.07477633144907513

# %%
#T_test one sample for B
t_statisticB, p_valueB = stats.ttest_1samp(shingles['B'], 0.35,nan_policy='omit')
p_valueB=p_valueB/2
print('One sample t test \nt statistic: {0} p value for B: {1} '.format(t_statisticB, p_valueB))
# Out:
# One sample t test
# t statistic: -3.1003313069986995 p value for B: 0.0020904774003191826

# %%
#2 Sample T Test
t_statistic, p_value = stats.ttest_ind(shingles['A'],shingles['B'], nan_policy='omit')
print('2 Sample T test  \nt statistic: {0} p value: {1} '.format(t_statistic, p_value))
# Out:
# 2 Sample T test
# t statistic: 1.2896282719661123 p value: 0.2017496571835306
